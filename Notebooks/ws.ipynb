# %%
from bs4 import BeautifulSoup as BS
import requests
import pandas as pd
from datetime import datetime, timedelta

# %%
response = requests.get("https://realpython.github.io/fake-jobs/")

# %%
soup = BS(response.text)

# %%
job_titles = soup.findAll("h2")

# %% [markdown]
# ### First Job Title

# %%
job_titles[0].text
# Out:
# 'Senior Python Developer'

# %% [markdown]
# ### Getting Companies, Dates, and Locations

# %%
companies = soup.findAll('h3', class_='subtitle')
locations = soup.findAll('p', class_='location')
dates = soup.findAll('time')

# %%
dates_t = [i.text for i in dates]
dates_t
# Out:
# ['2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
#  '2021-04-08',
# ...

# %%
locations_t = [i.text.strip() for i in locations]
locations_t
# Out:
# ['Stewartbury, AA',
#  'Christopherville, AA',
#  'Port Ericaburgh, AA',
#  'East Seanview, AP',
#  'North Jamieview, AP',
#  'Davidville, AP',
#  'South Christopher, AE',
#  'Port Jonathan, AE',
#  'Osbornetown, AE',
#  'Scotttown, AP',
#  'Ericberg, AE',
#  'Ramireztown, AE',
#  'Figueroaview, AA',
#  'Kelseystad, AA',
#  'Williamsburgh, AE',
#  'Mitchellburgh, AE',
#  'West Jessicabury, AA',
#  'Maloneshire, AE',
#  'Johnsonton, AA',
#  'South Davidtown, AP',
#  'Port Sara, AE',
#  'Marktown, AA',
#  'Laurenland, AE',
#  'Lauraton, AP',
#  'South Tammyberg, AP',
#  'North Brandonville, AP',
#  'Port Robertfurt, AA',
#  'Burnettbury, AE',
#  'Herbertside, AA',
#  'Christopherport, AP',
#  'West Victor, AE',
#  'Port Aaron, AP',
#  'Loribury, AA',
#  'Angelastad, AP',
#  'Larrytown, AE',
#  'West Colin, AP',
#  'West Stephanie, AP',
#  'Laurentown, AP',
#  'Wrightberg, AP',
#  'Alberttown, AE',
#  'Brockburgh, AE',
#  'North Jason, AE',
#  'Arnoldhaven, AE',
#  'Lake Destiny, AP',
# ...

# %%
companies_t = [i.text for i in companies]
companies_t
# Out:
# ['Payne, Roberts and Davis',
#  'Vasquez-Davidson',
#  'Jackson, Chambers and Levy',
#  'Savage-Bradley',
#  'Ramirez Inc',
#  'Rogers-Yates',
#  'Kramer-Klein',
#  'Meyers-Johnson',
#  'Hughes-Williams',
#  'Jones, Williams and Villa',
#  'Garcia PLC',
#  'Gregory and Sons',
#  'Clark, Garcia and Sosa',
#  'Bush PLC',
#  'Salazar-Meyers',
#  'Parker, Murphy and Brooks',
#  'Cruz-Brown',
#  'Macdonald-Ferguson',
#  'Williams, Peterson and Rojas',
#  'Smith and Sons',
#  'Moss, Duncan and Allen',
#  'Gomez-Carroll',
#  'Manning, Welch and Herring',
#  'Lee, Gutierrez and Brown',
#  'Davis, Serrano and Cook',
#  'Smith LLC',
#  'Thomas Group',
#  'Silva-King',
#  'Pierce-Long',
#  'Walker-Simpson',
#  'Cooper and Sons',
#  'Donovan, Gonzalez and Figueroa',
#  'Morgan, Butler and Bennett',
#  'Snyder-Lee',
#  'Harris PLC',
#  'Washington PLC',
#  'Brown, Price and Campbell',
#  'Mcgee PLC',
#  'Dixon Inc',
#  'Thompson, Sheppard and Ward',
#  'Adams-Brewer',
#  'Schneider-Brady',
# ...

# %%
df = pd.DataFrame()
df['location'] = locations_t
df['date'] = dates_t
df['company'] = companies_t
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   location  100 non-null    object
#  1   date      100 non-null    object
#  2   company   100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# # 2.

# %%
buttons = soup.findAll('a', text="Apply")

# %%
apply_links = [i.get('href') for i in buttons]
apply_links
# Out:
# ['https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html',
#  'https://realpython.github.io/fake-jobs/jobs/energy-engineer-1.html',
#  'https://realpython.github.io/fake-jobs/jobs/legal-executive-2.html',
#  'https://realpython.github.io/fake-jobs/jobs/fitness-centre-manager-3.html',
#  'https://realpython.github.io/fake-jobs/jobs/product-manager-4.html',
#  'https://realpython.github.io/fake-jobs/jobs/medical-technical-officer-5.html',
#  'https://realpython.github.io/fake-jobs/jobs/physiological-scientist-6.html',
#  'https://realpython.github.io/fake-jobs/jobs/textile-designer-7.html',
#  'https://realpython.github.io/fake-jobs/jobs/television-floor-manager-8.html',
#  'https://realpython.github.io/fake-jobs/jobs/waste-management-officer-9.html',
#  'https://realpython.github.io/fake-jobs/jobs/software-engineer-python-10.html',
#  'https://realpython.github.io/fake-jobs/jobs/interpreter-11.html',
# ...

# %%
df['apply_link'] = apply_links
df.head()
# Out:
#                location        date                     company  \
# 0       Stewartbury, AA  2021-04-08    Payne, Roberts and Davis
# 1  Christopherville, AA  2021-04-08            Vasquez-Davidson
# 2   Port Ericaburgh, AA  2021-04-08  Jackson, Chambers and Levy
# 3     East Seanview, AP  2021-04-08              Savage-Bradley
# 4   North Jamieview, AP  2021-04-08                 Ramirez Inc
#
#                                           apply_link
# 0  https://realpython.github.io/fake-jobs/jobs/se...
# 1  https://realpython.github.io/fake-jobs/jobs/en...
# 2  https://realpython.github.io/fake-jobs/jobs/le...
# 3  https://realpython.github.io/fake-jobs/jobs/fi...
# 4  https://realpython.github.io/fake-jobs/jobs/pr...

# %% [markdown]
# # 3

# %%
first_description = df.iloc[0]['apply_link']

# %%
first_description
# Out:
# 'https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html'

# %%
response = requests.get(first_description)

# %%
soup2 = BS(response.text)

# %%
def get_job_description(url):
    response = requests.get(url)
    soup = BS(response.text)
    desc_p = soup.find('div', class_="content")
    desc_p = desc_p.find('p')
    return desc_p.text

# %%
df['description'] = df['apply_link'].apply(get_job_description)
df.head()
# Out:
#                location        date                     company  \
# 0       Stewartbury, AA  2021-04-08    Payne, Roberts and Davis
# 1  Christopherville, AA  2021-04-08            Vasquez-Davidson
# 2   Port Ericaburgh, AA  2021-04-08  Jackson, Chambers and Levy
# 3     East Seanview, AP  2021-04-08              Savage-Bradley
# 4   North Jamieview, AP  2021-04-08                 Ramirez Inc
#
#                                           apply_link  \
# 0  https://realpython.github.io/fake-jobs/jobs/se...
# 1  https://realpython.github.io/fake-jobs/jobs/en...
# 2  https://realpython.github.io/fake-jobs/jobs/le...
# 3  https://realpython.github.io/fake-jobs/jobs/fi...
# 4  https://realpython.github.io/fake-jobs/jobs/pr...
#
#                                          description
# 0  Professional asset web application environment...
# 1  Party prevent live. Quickly candidate change a...
# 2  Administration even relate head color. Staff b...
# ...

# %%
df.iloc[1].description
# Out:
# <p>Party prevent live. Quickly candidate change although. Together type music hospital. Every speech support time operation wear often.</p>

# %% [markdown]
# # Done

# %% [markdown]
# # Bonus

# %%
bb_url = "https://www.billboard.com/charts/hot-100/"
response_bb = requests.get(bb_url)
bs_bb = BS(response_bb.text)

# %%
df_bb = bs_bb.find('div', class_='chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max')
df_bb
# Out:
# <div class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max">
# <div class="chart-results-list-header // lrv-a-unstyle-list lrv-u-text-align-center lrv-u-background-color-brand-primary lrv-u-color-white lrv-u-flex lrv-u-align-items-center lrv-u-text-transform-uppercase lrv-u-line-height-small u-z-index-4 lrv-u-position-relative">
# <div class="o-chart-results-list-header__item // lrv-u-padding-tb-075 u-width-100 u-width-55@mobile-max u-width-55@tablet-only">
# <span class="c-span a-font-primary-medium-xxs u-font-size-11@mobile-max u-letter-spacing-00 u-line-height-125 lrv-u-display-block">
#
# 	This Week
# </span>
# </div>
# <div class="o-chart-results-list-header__item // lrv-u-padding-tb-075 u-width-100 u-width-67@mobile-max u-flex-order-n1@mobile-max">
# <span class="c-span a-font-primary-medium-xxs u-font-size-11@mobile-max u-letter-spacing-00 u-line-height-125 lrv-u-display-block">
# </span>
# </div>
# ...

# %%
the_rest = df_bb.find_all('div', class_="o-chart-results-list-row-container")

# %%
df_bbb = pd.DataFrame()
df_bbb['this_week'] = [ i.find('span').text.strip() for i in the_rest]
df_bbb['Song'] = [i.find('h3').text.strip() for i in the_rest]
df_bbb['artist'] = [i.find('h3').find_next('span').text.strip() for i in the_rest]
df_bbb['peak'] = [i.find('ul').find('ul').find_all('li')[4].text.strip() for i in the_rest]
df_bbb['weeks_on_chart'] = [i.find('ul').find('ul').find_all('li')[5].text.strip() for i in the_rest]
df_bbb['last_week'] = [i.find('ul').find('ul').find_all('li')[3].text.strip() for i in the_rest]

# %%
print(the_rest[0].find('ul').find('ul').find_all('li')[4])
# Out:
# <li class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max">
# <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
# 	1
# </span>
# </li>

# %%
df_bbb.head()
# Out:
#   this_week                   Song                                artist peak  \
# 0         1            Lovin On Me                           Jack Harlow    1
# 1         2           Cruel Summer                          Taylor Swift    1
# 2         3                 Greedy                            Tate McRae    3
# 3         4  I Remember Everything  Zach Bryan Featuring Kacey Musgraves    1
# 4         5     Paint The Town Red                              Doja Cat    1
#
#   weeks_on_chart last_week
# 0              9         1
# 1             36         2
# 2             17         3
# 3             20         5
# 4             23         4

# %%
def get_chart(date):
    url = f"https://www.billboard.com/charts/hot-100/{date}/"
    response_bb = requests.get(url)
    bs_bb = BS(response_bb.text)
    df_bb = bs_bb.find('div', class_='chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max')
    the_rest = df_bb.find_all('div', class_="o-chart-results-list-row-container")
    df_bbb = pd.DataFrame()
    df_bbb['this_week'] = [ i.find('span').text.strip() for i in the_rest]
    df_bbb['Song'] = [i.find('h3').text.strip() for i in the_rest]
    df_bbb['artist'] = [i.find('h3').find_next('span').text.strip() for i in the_rest]
    df_bbb['peak'] = [i.find('ul').find('ul').find_all('li')[4].text.strip() for i in the_rest]
    df_bbb['weeks_on_chart'] = [i.find('ul').find('ul').find_all('li')[5].text.strip() for i in the_rest]
    df_bbb['last_week'] = [i.find('ul').find('ul').find_all('li')[3].text.strip() for i in the_rest]
    return df_bbb

# %%
df_prev_week = get_chart('2024-01-13')

# %%
df_prev_week
# Out:
#    this_week                         Song  \
# 0          1                  Lovin On Me
# 1          2                 Cruel Summer
# 2          3                       Greedy
# 3          4           Paint The Town Red
# 4          5        I Remember Everything
# ..       ...                          ...
# 95        96                   Tourniquet
# 96        97                      Y Lloro
# 97        98     Murder On The Dancefloor
# 98        99                     Amargura
# 99       100  Wildflowers And Wild Horses
#
#                                   artist peak weeks_on_chart last_week
# 0                            Jack Harlow    1              8         9
# 1                           Taylor Swift    1             35        19
# 2                             Tate McRae    3             16        24
# 3                               Doja Cat    1             22        29
# 4   Zach Bryan Featuring Kacey Musgraves    1             19        31
# ...

# %% [markdown]
# ## Getting an array of 10 previous Sunday dates

# %%
format = '%Y-%m-%d'
pr_date = datetime.strptime('2024-01-13', format).date()
print(pr_date)
dates_arr = []
for i in range(10):
    pr_date = pr_date - timedelta(days=7)
    dates_arr.append(pr_date)
dates_arr
# Out:
# 2024-01-13
# [datetime.date(2024, 1, 6),
#  datetime.date(2023, 12, 30),
#  datetime.date(2023, 12, 23),
#  datetime.date(2023, 12, 16),
#  datetime.date(2023, 12, 9),
#  datetime.date(2023, 12, 2),
#  datetime.date(2023, 11, 25),
#  datetime.date(2023, 11, 18),
#  datetime.date(2023, 11, 11),
#  datetime.date(2023, 11, 4)]

# %%
dates_arr = [i.strftime(format) for i in dates_arr]
dates_arr
# Out:
# ['2024-01-06',
#  '2023-12-30',
#  '2023-12-23',
#  '2023-12-16',
#  '2023-12-09',
#  '2023-12-02',
#  '2023-11-25',
#  '2023-11-18',
#  '2023-11-11',
#  '2023-11-04']

# %%
ten_weeks_df = [get_chart(i) for i in dates_arr]
ten_weeks_df = pd.concat(ten_weeks_df)
ten_weeks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   this_week       1000 non-null   object
#  1   Song            1000 non-null   object
#  2   artist          1000 non-null   object
#  3   peak            1000 non-null   object
#  4   weeks_on_chart  1000 non-null   object
#  5   last_week       1000 non-null   object
# dtypes: object(6)
# memory usage: 54.7+ KB

# %%
ten_weeks_df
# Out:
#    this_week                               Song  \
# 0          1  Rockin' Around The Christmas Tree
# 1          2    All I Want For Christmas Is You
# 2          3                   Jingle Bell Rock
# 3          4                     Last Christmas
# 4          5            A Holly Jolly Christmas
# ..       ...                                ...
# 95        96                  Call Your Friends
# 96        97                        The Painter
# 97        98                               Deli
# 98        99                   Bahamas Promises
# 99       100                       Say My Grace
#
#                            artist peak weeks_on_chart last_week
# 0                      Brenda Lee    1             58         2
# 1                    Mariah Carey    1             65         1
# 2                     Bobby Helms    3             56         3
# 3                           Wham!    4             38         4
# ...
